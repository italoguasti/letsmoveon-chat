# %% [markdown]
# <a href="https://colab.research.google.com/github/italoguasti/letsmoveon-chat/blob/main/letsmoveonchat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai
import random
from google.colab import drive
from IPython.display import Image

GOOGLE_API_KEY='API_KEY'
genai.configure(api_key=GOOGLE_API_KEY)

# %%
generation_config = {
    'candidate_count': 1,
    'temperature': 0.5,
}

safety_settings = {
    'HARASSMENT': 'BLOCK_NONE',
    'HATE': 'BLOCK_NONE',
    'SEXUAL': 'BLOCK_NONE',
    'DANGEROUS': 'BLOCK_NONE',
}

# %%
model = genai.GenerativeModel(model_name="gemini-1.0-pro",
                              generation_config=generation_config,
                              safety_settings=safety_settings)

chat = model.start_chat(history=[])

# %%
print('Olá!')
print('Seja bem vindo(a) ao Lets move on, juntos correremos, aqui você aprenderá como dar aquele upgrade em seu HP treinando em alguns dias da semana \o/.')

prompt = input('Digite o seu peso: \n')
response = chat.send_message(f'Faça o calculo da quantidade de água diária que deve ser ingerida baseada em meu peso {prompt} e responda da seguinte forma: De acordo com o seu peso corporal é indicado que você tome (quantidade) de água por dia.')
print(response.text)
print('--------------------------------------------------------------------------------\n')

print('Sendo assim, estamos aqui para te ajudar a começar a se exercitar e mudar a sua vida!')
print('Você sabia? A corrida melhora sua saúde cardiovascular, a sua saúde mental, o seu sono, ajuda a reduzir o estresse, a ansiedade, a depressão e de quebra ainda te ajuda no seu dia a dia tendo mais foco e mais disposição.')
print('Bora superar esse desafio pessoal?\n')
print('--------------------------------------------------------------------------------\n')

print('Conta pra gente sobre você e desenvolveremos uma planilha de treinos do 0 especial para você com todo carinho <3')
nivelCorrida = input('Digite o nível em que você acredite estar na corrida (Iniciante, Intermediário ou Avançado): \n')
response = chat.send_message(f'Crie uma planilha de treinos de corrida para uma pessoa de nível {nivelCorrida}. Independente do nível da pessoa os treinos devem ser na terça-feira: corrida leve esforço médio kilometragem de nível {nivelCorrida}; quinta-feira: treino de tiros aquecendo por 2km com trote leve, desaquecendo com 1km trote leve, a distância e o tempo dos tiros devem ser de acordo com o nível {nivelCorrida}; e sábado ou domingo: treino longo, distancia de acordo com o de nível {nivelCorrida}. Não adicione a sua resposta distância e tempo de acordo com o nível do usuário.\n')
print('\n', response.text)

print('--------------------------------------------------------------------------------\n')

print('Parabéns! Bora correr.')
print('Uhuuul, agora você faz parte do time: \n')

# Monta o Google Drive (descomente e rode o comando caso ainda não tenha feito)
# drive.mount('/content/drive')

# Caminho para a pasta com as imagens no Drive
pasta_imagens = '/content/drive/My Drive/chat-run-images/'

# Lista de nomes das imagens (verifique os nomes e extensões!)
imagens = ['ligeirinho.png', 'papaleguas.png', 'sonic.png', 'taz.png']

# Escolhe uma imagem aleatória
imagem_aleatoria = random.choice(imagens)

# Caminho completo para a imagem aleatória
caminho_imagem = pasta_imagens + imagem_aleatoria

# Exibe a imagem
Image(filename=caminho_imagem)
# print('--------------------------------------------------------------------------------\n')

# prompt = input('Diga-me suas dúvidas: ')

# while prompt != 'fim':
#   response = chat.send_message(prompt)
#   print('Resposta: ', response.text, '\n')
#   prompt = input('Diga-me suas dúvidas: ')
# Out:
# Olá!
# Seja bem vindo(a) ao Lets move on, juntos correremos, aqui você aprenderá como dar aquele upgrade em seu HP treinando em alguns dias da semana \o/.
# Digite o seu peso:
# 56
# De acordo com o seu peso corporal de 56 kg, é indicado que você tome **2,2 litros** de água por dia.
# --------------------------------------------------------------------------------
#
# Sendo assim, estamos aqui para te ajudar a começar a se exercitar e mudar a sua vida!
# Você sabia? A corrida melhora sua saúde cardiovascular, a sua saúde mental, o seu sono, ajuda a reduzir o estresse, a ansiedade, a depressão e de quebra ainda te ajuda no seu dia a dia tendo mais foco e mais disposição.
# Bora superar esse desafio pessoal?
#
# --------------------------------------------------------------------------------
#
# Conta pra gente sobre você e desenvolveremos uma planilha de treinos do 0 especial para você com todo carinho <3
# ...
